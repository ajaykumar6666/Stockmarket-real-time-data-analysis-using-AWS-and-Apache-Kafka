# %%
from kafka import KafkaConsumer
from time import sleep
from json import dumps,loads
import json
from s3fs import S3FileSystem

# %%
consumer = KafkaConsumer(
    'demo_testing33',
     bootstrap_servers=['3.15.221.170:9092'], #add your IP here
    value_deserializer=lambda x: loads(x.decode('utf-8')))

# %%
# for c in consumer:
#     print(c.value)

# %%
s3 = S3FileSystem()

# %%
for i in consumer:
    print(i.value)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 for i in consumer:
#       2     print(i.value)
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/group.py:708, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     705 if self._coordinator.need_rejoin():
#     706     return {}
# --> 708 records, _ = self._fetcher.fetched_records(max_records, update_offsets=update_offsets)
#     709 return records
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/fetcher.py:344, in Fetcher.fetched_records(self, max_records, update_offsets)
#     342         break
#     343     completion = self._completed_fetches.popleft()
# --> 344     self._next_partition_records = self._parse_fetched_data(completion)
#     345 else:
#     346     records_remaining -= self._append(drained,
#     347                                       self._next_partition_records,
#     348                                       records_remaining,
#     349                                       update_offsets)
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/fetcher.py:818, in Fetcher._parse_fetched_data(self, completed_fetch)
#     814 if records.has_next():
#     815     log.debug("Adding fetched record for partition %s with"
#     816               " offset %d to buffered record list", tp,
#     817               position)
# --> 818     unpacked = list(self._unpack_message_set(tp, records))
#     819     parsed_records = self.PartitionRecords(fetch_offset, tp, unpacked)
#     820     last_offset = unpacked[-1].offset
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/fetcher.py:473, in Fetcher._unpack_message_set(self, tp, records)
#     469 value_size = len(record.value) if record.value is not None else -1
#     470 key = self._deserialize(
#     471     self.config['key_deserializer'],
#     472     tp.topic, record.key)
# --> 473 value = self._deserialize(
#     474     self.config['value_deserializer'],
#     475     tp.topic, record.value)
#     476 headers = record.headers
#     477 header_size = sum(
#     478     len(h_key.encode("utf-8")) + (len(h_val) if h_val is not None else 0) for h_key, h_val in
#     479     headers) if headers else -1
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/fetcher.py:511, in Fetcher._deserialize(self, f, topic, bytes_)
#     509 if isinstance(f, Deserializer):
#     510     return f.deserialize(topic, bytes_)
# --> 511 return f(bytes_)
#
# Cell In[10], line 4, in <lambda>(x)
#       1 consumer = KafkaConsumer(
#       2     'demo_testing33',
#       3      bootstrap_servers=['3.15.221.170:9092'], #add your IP here
# ----> 4     value_deserializer=lambda x: loads(x.decode('utf-8')))
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
arn:aws:s3:::stockmarket-kafka-project

# %%
for count, i in enumerate(consumer):
    with s3.open("s3://stockmarket-kafka-project/stock_market_{}.json".format(count), 'w') as file:
        json.dump(i.value, file)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 for count, i in enumerate(consumer):
#       2     with s3.open("s3://stockmarket-kafka-project/stock_market_{}.json".format(count), 'w') as file:
#       3         json.dump(i.value, file)
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/group.py:708, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     705 if self._coordinator.need_rejoin():
#     706     return {}
# --> 708 records, _ = self._fetcher.fetched_records(max_records, update_offsets=update_offsets)
#     709 return records
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/fetcher.py:344, in Fetcher.fetched_records(self, max_records, update_offsets)
#     342         break
#     343     completion = self._completed_fetches.popleft()
# --> 344     self._next_partition_records = self._parse_fetched_data(completion)
#     345 else:
#     346     records_remaining -= self._append(drained,
#     347                                       self._next_partition_records,
#     348                                       records_remaining,
#     349                                       update_offsets)
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/fetcher.py:818, in Fetcher._parse_fetched_data(self, completed_fetch)
#     814 if records.has_next():
#     815     log.debug("Adding fetched record for partition %s with"
#     816               " offset %d to buffered record list", tp,
#     817               position)
# --> 818     unpacked = list(self._unpack_message_set(tp, records))
#     819     parsed_records = self.PartitionRecords(fetch_offset, tp, unpacked)
#     820     last_offset = unpacked[-1].offset
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/fetcher.py:473, in Fetcher._unpack_message_set(self, tp, records)
#     469 value_size = len(record.value) if record.value is not None else -1
#     470 key = self._deserialize(
#     471     self.config['key_deserializer'],
#     472     tp.topic, record.key)
# --> 473 value = self._deserialize(
#     474     self.config['value_deserializer'],
#     475     tp.topic, record.value)
#     476 headers = record.headers
#     477 header_size = sum(
#     478     len(h_key.encode("utf-8")) + (len(h_val) if h_val is not None else 0) for h_key, h_val in
#     479     headers) if headers else -1
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/fetcher.py:511, in Fetcher._deserialize(self, f, topic, bytes_)
#     509 if isinstance(f, Deserializer):
#     510     return f.deserialize(topic, bytes_)
# --> 511 return f(bytes_)
#
# Cell In[10], line 4, in <lambda>(x)
#       1 consumer = KafkaConsumer(
#       2     'demo_testing33',
#       3      bootstrap_servers=['3.15.221.170:9092'], #add your IP here
# ----> 4     value_deserializer=lambda x: loads(x.decode('utf-8')))
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/json/decoder.py:355, in JSONDecoder.raw_decode(self, s, idx)
#     353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
# --> 355     raise JSONDecodeError("Expecting value", s, err.value) from None
#     356 return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %%
for c in consumer:
    print(c.value)
# Out:
# {'Index': 'SSMI', 'Date': '2015-09-24', 'Open': 8442.25, 'High': 8449.290039, 'Low': 8260.410156, 'Close': 8278.070313, 'Adj Close': 8278.070313, 'Volume': 61856700.0, 'CloseUSD': 9188.65804743}
# {'Index': 'NYA', 'Date': '1967-08-09', 'Open': 562.419983, 'High': 562.419983, 'Low': 562.419983, 'Close': 562.419983, 'Adj Close': 562.419983, 'Volume': 0.0, 'CloseUSD': 562.419983}
# {'Index': 'J203.JO', 'Date': '2012-11-15', 'Open': 37241.78906, 'High': 37241.78906, 'Low': 36966.51172, 'Close': 37026.71875, 'Adj Close': 37026.71875, 'Volume': 0.0, 'CloseUSD': 2591.8703125}
# {'Index': 'N100', 'Date': '2010-02-11', 'Open': 644.419983, 'High': 647.710022, 'Low': 633.450012, 'Close': 639.27002, 'Adj Close': 639.27002, 'Volume': 468493300.0, 'CloseUSD': 779.9094244}
# {'Index': 'NYA', 'Date': '2011-01-13', 'Open': 8122.97998, 'High': 8148.950195, 'Low': 8101.459961, 'Close': 8119.430176, 'Adj Close': 8119.430176, 'Volume': 4310840000.0, 'CloseUSD': 8119.430176}
# {'Index': 'IXIC', 'Date': '2003-12-01', 'Open': 1972.969971, 'High': 1989.819946, 'Low': 1968.540039, 'Close': 1989.819946, 'Adj Close': 1989.819946, 'Volume': 1840020000.0, 'CloseUSD': 1989.819946}
# {'Index': 'IXIC', 'Date': '2016-06-28', 'Open': 4643.930176, 'High': 4692.97998, 'Low': 4643.930176, 'Close': 4691.870117, 'Adj Close': 4691.870117, 'Volume': 2074090000.0, 'CloseUSD': 4691.870117}
# {'Index': 'N100', 'Date': '2001-02-20', 'Open': 949.619995, 'High': 949.619995, 'Low': 949.619995, 'Close': 949.619995, 'Adj Close': 949.619995, 'Volume': 0.0, 'CloseUSD': 1158.5363939}
# {'Index': 'IXIC', 'Date': '1995-09-15', 'Open': 1062.939941, 'High': 1062.939941, 'Low': 1047.699951, 'Close': 1051.099976, 'Adj Close': 1051.099976, 'Volume': 520200000.0, 'CloseUSD': 1051.099976}
# {'Index': 'NYA', 'Date': '2006-08-17', 'Open': 8357.360352, 'High': 8375.070313, 'Low': 8330.530273, 'Close': 8354.070313, 'Adj Close': 8354.070313, 'Volume': 2458340000.0, 'CloseUSD': 8354.070313}
# {'Index': 'GSPTSE', 'Date': '1986-03-07', 'Open': 2914.199951, 'High': 2927.0, 'Low': 2914.199951, 'Close': 2927.0, 'Adj Close': 2919.567139, 'Volume': 26090000.0, 'CloseUSD': 2429.41}
# {'Index': 'IXIC', 'Date': '2000-06-23', 'Open': 3950.050049, 'High': 3957.679932, 'Low': 3830.22998, 'Close': 3845.340088, 'Adj Close': 3845.340088, 'Volume': 1344960000.0, 'CloseUSD': 3845.340088}
# {'Index': 'N225', 'Date': '1994-09-21', 'Open': 19788.85938, 'High': 19961.58984, 'Low': 19691.43945, 'Close': 19885.38086, 'Adj Close': 19885.38086, 'Volume': 0.0, 'CloseUSD': 198.8538086}
# {'Index': 'IXIC', 'Date': '1975-09-08', 'Open': 77.459999, 'High': 77.459999, 'Low': 77.459999, 'Close': 77.459999, 'Adj Close': 77.459999, 'Volume': 0.0, 'CloseUSD': 77.459999}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 for c in consumer:
#       2     print(c.value)
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File ~/opt/anaconda3/envs/capstone/lib/python3.9/selectors.py:562, in KqueueSelector.select(self, timeout)
#     560 ready = []
#     561 try:
# --> 562     kev_list = self._selector.control(None, max_ev, timeout)
#     563 except InterruptedError:
#     564     return ready
#
# KeyboardInterrupt:
